# %%
import pandas as pd

# %%
csv1 = "JC-202204-citibike-tripdata.csv"
csv2 = "JC-202205-citibike-tripdata.csv"
csv3 = "JC-202206-citibike-tripdata.csv"

# %%
csv1df = pd.read_csv(csv1)
csv2df = pd.read_csv(csv2)
csv3df = pd.read_csv(csv3)
csv1df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      919C40A703A965D7  electric_bike  2022-04-15 15:02:20
# 1      3B40831921DAD6C1   classic_bike  2022-04-08 10:20:55
# 2      69C5C0766309F73D  electric_bike  2022-04-09 14:14:04
# 3      304B82055A1D4A24   classic_bike  2022-04-05 19:43:37
# 4      1CB760ECBCB08609   classic_bike  2022-04-17 11:25:26
# ...                 ...            ...                  ...
# 62523  13C1C453508F048A   classic_bike  2022-04-24 12:52:09
# 62524  B7E454B8886D7826  electric_bike  2022-04-30 11:45:56
# 62525  20D6A9E7C8291984   classic_bike  2022-04-28 14:28:34
# 62526  2AEB863A4F683CAE  electric_bike  2022-04-09 17:37:14
# 62527  AB2C885E7051B2D4   classic_bike  2022-04-02 15:54:12
#
#                   ended_at                            start_station_name  \
# 0      2022-04-15 15:57:16                                Pershing Field
# 1      2022-04-08 10:25:29                             JC Medical Center
# ...

# %%
newdf = csv1df.append(csv2df)
finaldf = newdf.append(csv3df)
finaldf = finaldf.dropna()
finaldf
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       919C40A703A965D7  electric_bike  2022-04-15 15:02:20
# 1       3B40831921DAD6C1   classic_bike  2022-04-08 10:20:55
# 2       69C5C0766309F73D  electric_bike  2022-04-09 14:14:04
# 3       304B82055A1D4A24   classic_bike  2022-04-05 19:43:37
# 4       1CB760ECBCB08609   classic_bike  2022-04-17 11:25:26
# ...                  ...            ...                  ...
# 103294  25AD34565A260732   classic_bike  2022-06-17 16:03:36
# 103295  8A4181FCE9439036   classic_bike  2022-06-25 14:14:26
# 103296  28C8501BCB596743  electric_bike  2022-06-04 08:57:04
# 103297  D28575BBFF3A0B57   classic_bike  2022-06-17 06:11:05
# 103298  A914FEF9390C201C  electric_bike  2022-06-02 18:15:17
#
#                    ended_at                            start_station_name  \
# 0       2022-04-15 15:57:16                                Pershing Field
# 1       2022-04-08 10:25:29                             JC Medical Center
# ...

# %%
finaldf.to_csv('citybike.csv')
